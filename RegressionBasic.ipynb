# %%
import pandas as pd
from pandas import Series as s , DataFrame as df
import numpy as np

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import seaborn as sb
from matplotlib import pyplot as plt, rcParams as rc

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor


# %matplotlib inline
rc["figure.figsize"] = 10,6


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
data = pd.read_csv("hp_data.csv")

# %%
def getDataAllDetails(data):
    print("Return a tuple representing the dimensionality of the DF.  :  ",data.shape)
    print("Count of Each Data                                          :  ",data.count())
    print("Start,End,Column,Step                                       :  ",data.axes)
    print("Column                                                      :  ",data.columns)
    print("First 5 items                                               :  ",data.head(2))
    print("Missing Vlaue                                               :  ",data.isnull().sum())
    print("information                                                 :  ",data.info())
    print("Description                                                 :  ",data.describe())
    print("Size(Row*Column) represent the no of elements in this object:  ",data.size)
    print("Return unbiased skew over requested axis                    :  ",data.skew())
    print("std err of mean                                             :  ",data.sem())
    print("Return sample standard deviation over requested axis        :  ",data.std())
    print("sum of every data                                           :  ",data.sum())
    print("Copy Data to other                                          :  ",data.copy())
    print("Correlation of Data                                         :  ",data.corr())
    print("Covariance of Columns                                       :  ",data.cov())
    print("cumulative sum over data                                    :  ",data.cumsum())
    print("cumulative min or max                                       :  ",data.cummin())
    print("Remove duplicate row                                        :  ",data.drop_duplicates())
    print("Romove missing Value                                        :  ",data.dropna())
    print("Drop Specify Label                                          :  ",data.drop(labels=[2,49,78,88]))
    print("Drop Specify Label(Plz check inplace true means)            :  ",data.drop(labels=[2,49,78,88],inplace=True))
    print("Tell about Data Types                                       :  ",data.dtypes)
    print("Find the Duplicate Row                                      :  ",data.duplicated())
    print("DataFrame is Empty(True) or not(False)                      :  ",data.empty)
    print("Expanding                                                   :  ",data.expanding())
    print("Fill Na/Nan Value using Specify metho                       :  ",data.fillna)
    #print("rows/columns of DF A/c to labels in specified index   :  ",data.filter)
    #print(" check it(fill backward)          :  ",data.bfill())
    #print(" check it(fill forward)         :  ",data.ffill())
    #print("    check it ?      :  ",data.from_csv)
    #print("       check it ?   :  ",data.from_dict,data.from_items,data.from_records)
    print("Return(indication of sparse/dense and dtype) in Df          :  ",data.from_records)
    print("Tell about Data Types(check abobe ftypes)                   :  ",data.dtypes)
    print("Return counts of unique dtypes in this object               :  ",data.get_dtype_counts())
    print("Return counts of unique dtypes in this object(dense)        :  ",data.get_ftype_counts())
    print("Return ndarray after convert sparse values to dense         :  ",data.get_values())
    #print("   check it       :  ",data.groupby)
    print("RangeIndex(start=0,stop=data size, step=1)                  :  ",data.index)
    print("concise summary of DF,Dtypes,Memory,Shape,Many Info         :  ",data.info)
    #print("    check it      :  ",data.insert)
    #print("  check it        :  ",data.interpolate)
    #print("   check it       :  ",data.is_copy)
    print("Detect the Missing Value(Both Same isna & isnull )           :  ",data.isna().sum(),data.isnull().sum())
    #print("    check it      :  ",data.join)
    print("Get the 'info axis(same as columns : data.columns)           :  ",data.keys,data.columns)
    print("unbiased kurt over requested axis using Fisher's def         :  ",data.kurt,data.kurtosis)
    print("both are same data.kurt & data.kurtosis                      :  ",data.kurt,data.kurtosis)
    print("Return index for last non-NA/null value                      :  ",data.last_valid_index())
    print("mean absolute deviation value for the requested axis         :  ",data.mad())
    print("Returns the maximum of the values in the object              :  ",data.max())
    print("Returns the minimum of the values in the object              :  ",data.min())
    print("Return the mean of the values for the requested axis         :  ",data.mean())
    print("Return the median of the values for the request axis         :  ",data.median())
    #print("   check it       :  ",data.melt())
    print("Return the memory usage of each column in bytes.             :  ",data.memory_usage())
    #print("  check it        :  ",data.merge)
    #print("    check it (mod, mul,multiply)      :  ",data,mod,data.mul,data.multiply)
    print("Return an int representing the no of axes/array dims         :  ",data.ndim)
    print("row's DF sorted by the n smallest values of `columns         :  ",data.nsmallest(n=10,columns="price"))
    print("row's DF sorted by the n largest values of `columns          :  ",data.nlargest(n=10,columns="price"))
    print("Find existing(non-missing) values(Same:notna,notnull)        :  ",data.notna(),data.notnull())
    print("Series with no of distinct observations over requested axis  :  ",data.nunique(axis=0))
    #print("     check it     :  ",data.pct_change)
    #print(" check it(pivot,pivot_table)         :  ",data.pivot,data.pivot_table)
    print("Return item & drop/delete from frame.Raise Error,if not found:  ",data.pop("price"))
    #print("  check it        :  ",data.pow)
    print("product/prod same of the value for the request(default axis=0):  ",data.prod(axis=0),data.product(axis=0))
    print("values quantile over requested axis, a la numpy.percentile.   :  ",data.quantile())
    #print("    check it      :  ",data.query)
    #print("       check it   :  ",data.radd)
    print("Compute numerical data rank(1 through n)along axis.Equal values:  ",data.rank(numeric_only=True,axis=0))
    print("Conform DF to new index with optional filling logic,placing    :  ",data.reindex().sum())
    #print("check it  :  ",data.rename,data.rename_axis,data.reorder_levels,data.replace,data.resample,data.resample)
    #print("   check it :  ",data.reset_index(),data.rmod,data.rmul,data.rolling,data.rpow,data.rsub,data.rtruediv)
    print("Round a DataFrame to a variable number of decimal places.      :  ",data.round())
    print("Return a random sample of items from an axis of object.        :  ",data.sample())
    print("check it      :  ",data.select,data.set_index,data.set_value)
    print("Return unbiased standard error of the mean over requested axis.:  ",data.sem())
    print("Shift index by desired no of periods with an optional time freq:  ",data.shift(axis=0,periods=3))
    print("Equivalent to `shift` without copying data                     :  ",data.slice_shift(axis=0,periods=5))
    print("Sort object by labels (along an axis=0, default)               :  ",data.sort_index(axis=1,ascending=False))
    print("Sort by the values along either axis                           :  ",data.sort_values(by=["price","yearsOld"],axis=0,ascending=False))
    print("Sort multilevel index by chosen axis level(sort based on words):  ",data.sortlevel(level=0, axis=1, ascending=True))
    #print("Check it  :  ",data.stack(),data.sub,data.subtract())
    print("Display All Items(same as head(total no of items))             :  ",data.style)
    print("Interchange axes & swap values axes(swap rows to columns)      :  ",data.swapaxes(axis1=0,axis2=1,copy=False))
    print("Interchange axes & swap values axes appropriately              :  ",data.swaplevel(i=0,j=0,axis=0))
    #print(" check it    :  ",data.unstack,data.update())
    print("Return unbiased variance over requested axis.                  :  ",data.var(axis=0))
    #print("   check it       :  ",data.where,data.xs())

# %%
def graphDetail():
    print("Prints the values to a stream, or to sys.stdout by default boxplot      :  ",data.boxplot())
    print("Prints the values to a stream, or to sys.stdout by default hist         :  ",data.hist())
    print("Prints the values to a stream, or to sys.stdout by default plot         :  ",data.plot())
    #print("Prints the values to a stream, or to sys.stdout by default              :  ",data.boxplot())
    #print("Prints the values to a stream, or to sys.stdout by default              :  ",data.boxplot())

# %%
getDataAllDetails(data=data)
# Out:
# Return a tuple representing the dimensionality of the DF.  :   (3500, 10)
# Count of Each Data                                          :   Unnamed: 0    3500
# price         3500
# place         3500
# built         3500
# sqft          3500
# sale          3500
# yearsOld      3500
# floor         3500
# totalFloor    3500
# bhk           3500
# dtype: int64
# Start,End,Column,Step                                       :   [RangeIndex(start=0, stop=3500, step=1), Index(['Unnamed: 0', 'price', 'place', 'built', 'sqft', 'sale', 'yearsOld',
#        'floor', 'totalFloor', 'bhk'],
#       dtype='object')]
# Column                                                      :   Index(['Unnamed: 0', 'price', 'place', 'built', 'sqft', 'sale', 'yearsOld',
#        'floor', 'totalFloor', 'bhk'],
#       dtype='object')
# First 5 items                                               :      Unnamed: 0     price       place                 built  sqft    sale  \
# 0        1341   6300000  BTM Layout  Super built-up  Area  1450  Resale
# 1        2126  11500000   Yelahanka  Super built-up  Area  2190  Resale
#
#    yearsOld  floor  totalFloor  bhk
# 0         5      1           4    1
# 1         5      3           5    3
# Missing Vlaue                                               :   Unnamed: 0    0
# price         0
# place         0
# built         0
# sqft          0
# sale          0
# yearsOld      0
# floor         0
# totalFloor    0
# bhk           0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 10 columns):
# Unnamed: 0    3500 non-null int64
# price         3500 non-null int64
# place         3500 non-null object
# built         3500 non-null object
# sqft          3500 non-null int64
# sale          3500 non-null object
# yearsOld      3500 non-null int64
# floor         3500 non-null int64
# totalFloor    3500 non-null int64
# bhk           3500 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 273.5+ KB
# information                                                 :   None
# Description                                                 :           Unnamed: 0         price         sqft     yearsOld        floor  \
# count  3500.000000  3.500000e+03  3500.000000  3500.000000  3500.000000
# mean   1484.225714  8.067807e+06  1538.163143     7.602000     4.197714
# std     852.423418  4.984973e+06   416.264178     3.803196     4.782410
# min       0.000000  3.800000e+06  1019.000000     1.000000     1.000000
# 25%     737.750000  4.800000e+06  1200.000000     5.000000     1.000000
# 50%    1492.000000  6.600000e+06  1543.000000     5.000000     3.000000
# 75%    2218.250000  1.050000e+07  1784.000000    10.000000     4.000000
# max    2944.000000  4.750000e+07  4856.000000    15.000000    18.000000
#
#         totalFloor          bhk
# count  3500.000000  3500.000000
# mean      6.371429     4.197714
# std       4.461808     4.782410
# min       4.000000     1.000000
# 25%       4.000000     1.000000
# 50%       4.000000     3.000000
# 75%       5.000000     4.000000
# max      29.000000    18.000000
# Size(Row*Column) represent the no of elements in this object:   35000
# Return unbiased skew over requested axis                    :   Unnamed: 0   -0.026198
# price         3.160963
# sqft          2.060713
# yearsOld      0.196092
# floor         2.228048
# totalFloor    2.195012
# bhk           2.228048
# dtype: float64
# std err of mean                                             :   Unnamed: 0       14.408586
# price         84261.429676
# sqft              7.036149
# yearsOld          0.064286
# floor             0.080837
# totalFloor        0.075418
# bhk               0.080837
# dtype: float64
# Return sample standard deviation over requested axis        :   Unnamed: 0    8.524234e+02
# price         4.984973e+06
# sqft          4.162642e+02
# yearsOld      3.803196e+00
# floor         4.782410e+00
# totalFloor    4.461808e+00
# bhk           4.782410e+00
# dtype: float64
# sum of every data                                           :   Unnamed: 0                                              5194790
# price                                               28237325000
# place         BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# built         Super built-up  AreaSuper built-up  AreaSuper ...
# sqft                                                    5383571
# sale          ResaleResaleResaleResaleResaleResaleResaleResa...
# yearsOld                                                  26607
# floor                                                     14692
# totalFloor                                                22300
# bhk                                                       14692
# dtype: object
# Copy Data to other                                          :         Unnamed: 0     price                     place                 built  \
# 0           1341   6300000                BTM Layout  Super built-up  Area
# 1           2126  11500000                 Yelahanka  Super built-up  Area
# 2            816   3800000                Whitefield  Super built-up  Area
# 3           2708  10500000                Ambalipura  Super built-up  Area
# 4           1041  11500000                 Yelahanka  Super built-up  Area
# 5           2783  15000000       Devarabeesana Halli  Super built-up  Area
# 6            703   7350000            Yelachenahalli  Super built-up  Area
# 7             88  15000000       Devarabeesana Halli  Super built-up  Area
# 8           1973  10500000                Ambalipura  Super built-up  Area
# 9            256   4900000                  KR Puram  Super built-up  Area
# 10          1831   3800000                Whitefield  Super built-up  Area
# 11           464   3800000                Whitefield  Super built-up  Area
# 12          1102  15000000       Devarabeesana Halli  Super built-up  Area
# 13           902   4025000  Electronics City Phase 1  Super built-up  Area
# 14          2139   4025000  Electronics City Phase 1  Super built-up  Area
# 15           162   4800000      Abbaiah Reddy Layout        Built-up  Area
# 16            95  10500000                Ambalipura  Super built-up  Area
# 17           830   7900000            Subramanyapura  Super built-up  Area
# 18           581   4025000  Electronics City Phase 1  Super built-up  Area
# 19          1120   7350000            Yelachenahalli  Super built-up  Area
# 20          2559  11500000                 Yelahanka  Super built-up  Area
# 21           329  10500000                Ambalipura  Super built-up  Area
# 22          1783   4900000                  KR Puram  Super built-up  Area
# 23          2202  15000000       Devarabeesana Halli  Super built-up  Area
# 24          1073   3800000                Whitefield  Super built-up  Area
# 25          2005   4900000                  KR Puram  Super built-up  Area
# 26          2649   7350000            Yelachenahalli  Super built-up  Area
# 27           747   4025000  Electronics City Phase 1  Super built-up  Area
# 28           142   4800000      Abbaiah Reddy Layout        Built-up  Area
# 29          2677   6300000                BTM Layout  Super built-up  Area
# ...          ...       ...                       ...                   ...
# 3470         119   3800000                Whitefield  Super built-up  Area
# 3471         560   6300000                BTM Layout  Super built-up  Area
# 3472        2421   7350000            Yelachenahalli  Super built-up  Area
# 3473        2138   3800000                Whitefield  Super built-up  Area
# 3474        2180   7350000            Yelachenahalli  Super built-up  Area
# 3475        1108   6300000                BTM Layout  Super built-up  Area
# 3476         836   3800000                Whitefield  Super built-up  Area
# 3477        2011  15000000       Devarabeesana Halli  Super built-up  Area
# 3478         496   4800000      Abbaiah Reddy Layout        Built-up  Area
# 3479        1136   4900000                  KR Puram  Super built-up  Area
# 3480        2166   4900000                  KR Puram  Super built-up  Area
# 3481        1540   4800000      Abbaiah Reddy Layout        Built-up  Area
# 3482         734  11500000                 Yelahanka  Super built-up  Area
# 3483        2043   3800000                Whitefield  Super built-up  Area
# 3484        2214   4025000  Electronics City Phase 1  Super built-up  Area
# 3485        2240   7350000            Yelachenahalli  Super built-up  Area
# 3486        1154   4025000  Electronics City Phase 1  Super built-up  Area
# 3487        2771   7350000            Yelachenahalli  Super built-up  Area
# 3488         114   6300000                BTM Layout  Super built-up  Area
# 3489        2785   4025000  Electronics City Phase 1  Super built-up  Area
# 3490        2271   7350000            Yelachenahalli  Super built-up  Area
# 3491        1629  10500000                Ambalipura  Super built-up  Area
# 3492         227  10500000                Ambalipura  Super built-up  Area
# 3493        1282  10500000                Ambalipura  Super built-up  Area
# 3494         595  15000000       Devarabeesana Halli  Super built-up  Area
# 3495         636   3800000                Whitefield  Super built-up  Area
# 3496        1664   6300000                BTM Layout  Super built-up  Area
# 3497        1252   7350000            Yelachenahalli  Super built-up  Area
# 3498         903   4800000      Abbaiah Reddy Layout        Built-up  Area
# 3499        2183   3800000                Whitefield  Super built-up  Area
#
#       sqft    sale  yearsOld  floor  totalFloor  bhk
# 0     1450  Resale         5      1           4    1
# 1     2190  Resale         5      3           5    3
# 2     1019  Resale         1      2           5    2
# 3     1857  Resale        15      4           5    4
# 4     2190  Resale         5      3           5    3
# 5     1672  Resale        10      6          10    6
# 6     1330  Resale        10      1           4    1
# 7     1672  Resale        10      6          10    6
# 8     1857  Resale        15      4           5    4
# 9     1100  Resale         5      3           4    3
# 10    1019  Resale         1      2           5    2
# 11    1019  Resale         1      2           5    2
# 12    1672  Resale        10      6          10    6
# 13    1543  Resale        10      3           4    3
# 14    1543  Resale        10      3           4    3
# 15    1200  Resale        10      1           4    1
# 16    1857  Resale        15      4           5    4
# 17    1784  Resale         5     18          18   18
# 18    1543  Resale        10      3           4    3
# 19    1330  Resale        10      1           4    1
# 20    2190  Resale         5      3           5    3
# 21    1857  Resale        15      4           5    4
# 22    1100  Resale         5      3           4    3
# 23    1672  Resale        10      6          10    6
# 24    1019  Resale         1      2           5    2
# 25    1100  Resale         5      3           4    3
# 26    1330  Resale        10      1           4    1
# 27    1543  Resale        10      3           4    3
# 28    1200  Resale        10      1           4    1
# 29    1450  Resale         5      1           4    1
# ...    ...     ...       ...    ...         ...  ...
# 3470  1019  Resale         1      2           5    2
# 3471  1450  Resale         5      1           4    1
# 3472  1330  Resale        10      1           4    1
# 3473  1019  Resale         1      2           5    2
# 3474  1330  Resale        10      1           4    1
# 3475  1450  Resale         5      1           4    1
# 3476  1019  Resale         1      2           5    2
# 3477  1672  Resale        10      6          10    6
# 3478  1200  Resale        10      1           4    1
# 3479  1100  Resale         5      3           4    3
# 3480  1100  Resale         5      3           4    3
# 3481  1200  Resale        10      1           4    1
# 3482  2190  Resale         5      3           5    3
# 3483  1019  Resale         1      2           5    2
# 3484  1543  Resale        10      3           4    3
# 3485  1330  Resale        10      1           4    1
# 3486  1543  Resale        10      3           4    3
# 3487  1330  Resale        10      1           4    1
# 3488  1450  Resale         5      1           4    1
# 3489  1543  Resale        10      3           4    3
# 3490  1330  Resale        10      1           4    1
# 3491  1857  Resale        15      4           5    4
# 3492  1857  Resale        15      4           5    4
# 3493  1857  Resale        15      4           5    4
# 3494  1672  Resale        10      6          10    6
# 3495  1019  Resale         1      2           5    2
# 3496  1450  Resale         5      1           4    1
# 3497  1330  Resale        10      1           4    1
# 3498  1200  Resale        10      1           4    1
# 3499  1019  Resale         1      2           5    2
#
# [3500 rows x 10 columns]
# Correlation of Data                                         :               Unnamed: 0     price      sqft  yearsOld     floor  totalFloor  \
# Unnamed: 0    1.000000  0.030283  0.001018 -0.022503  0.005641    0.008018
# price         0.030283  1.000000  0.778364  0.215712  0.263472    0.402256
# sqft          0.001018  0.778364  1.000000  0.229461  0.356053    0.358946
# yearsOld     -0.022503  0.215712  0.229461  1.000000 -0.116427   -0.142562
# floor         0.005641  0.263472  0.356053 -0.116427  1.000000    0.958100
# totalFloor    0.008018  0.402256  0.358946 -0.142562  0.958100    1.000000
# bhk           0.005641  0.263472  0.356053 -0.116427  1.000000    0.958100
#
#                  bhk
# Unnamed: 0  0.005641
# price       0.263472
# sqft        0.356053
# yearsOld   -0.116427
# floor       1.000000
# totalFloor  0.958100
# bhk         1.000000
# Covariance of Columns                                       :                 Unnamed: 0         price          sqft      yearsOld  \
# Unnamed: 0  7.266257e+05  1.286827e+08  3.611915e+02 -7.295330e+01
# price       1.286827e+08  2.484996e+13  1.615157e+09  4.089656e+06
# sqft        3.611915e+02  1.615157e+09  1.732759e+05  3.632670e+02
# yearsOld   -7.295330e+01  4.089656e+06  3.632670e+02  1.446430e+01
# floor       2.299451e+01  6.281210e+06  7.088103e+02 -2.117629e+00
# totalFloor  3.049516e+01  8.946985e+06  6.666670e+02 -2.419148e+00
# bhk         2.299451e+01  6.281210e+06  7.088103e+02 -2.117629e+00
#
#                    floor    totalFloor           bhk
# Unnamed: 0  2.299451e+01  3.049516e+01  2.299451e+01
# price       6.281210e+06  8.946985e+06  6.281210e+06
# sqft        7.088103e+02  6.666670e+02  7.088103e+02
# yearsOld   -2.117629e+00 -2.419148e+00 -2.117629e+00
# floor       2.287144e+01  2.044412e+01  2.287144e+01
# totalFloor  2.044412e+01  1.990773e+01  2.044412e+01
# bhk         2.287144e+01  2.044412e+01  2.287144e+01
# cumulative sum over data                                    :        Unnamed: 0        price  \
# 0          1341      6300000
# 1          3467     17800000
# 2          4283     21600000
# 3          6991     32100000
# 4          8032     43600000
# 5         10815     58600000
# 6         11518     65950000
# 7         11606     80950000
# 8         13579     91450000
# 9         13835     96350000
# 10        15666    100150000
# 11        16130    103950000
# 12        17232    118950000
# 13        18134    122975000
# 14        20273    127000000
# 15        20435    131800000
# 16        20530    142300000
# 17        21360    150200000
# 18        21941    154225000
# 19        23061    161575000
# 20        25620    173075000
# 21        25949    183575000
# 22        27732    188475000
# 23        29934    203475000
# 24        31007    207275000
# 25        33012    212175000
# 26        35661    219525000
# 27        36408    223550000
# 28        36550    228350000
# 29        39227    234650000
# ...         ...          ...
# 3470    5151501  28039750000
# 3471    5152061  28046050000
# 3472    5154482  28053400000
# 3473    5156620  28057200000
# 3474    5158800  28064550000
# 3475    5159908  28070850000
# 3476    5160744  28074650000
# 3477    5162755  28089650000
# 3478    5163251  28094450000
# 3479    5164387  28099350000
# 3480    5166553  28104250000
# 3481    5168093  28109050000
# 3482    5168827  28120550000
# 3483    5170870  28124350000
# 3484    5173084  28128375000
# 3485    5175324  28135725000
# 3486    5176478  28139750000
# 3487    5179249  28147100000
# 3488    5179363  28153400000
# 3489    5182148  28157425000
# 3490    5184419  28164775000
# 3491    5186048  28175275000
# 3492    5186275  28185775000
# 3493    5187557  28196275000
# 3494    5188152  28211275000
# 3495    5188788  28215075000
# 3496    5190452  28221375000
# 3497    5191704  28228725000
# 3498    5192607  28233525000
# 3499    5194790  28237325000
#
#                                                   place  \
# 0                                            BTM Layout
# 1                                   BTM LayoutYelahanka
# 2                         BTM LayoutYelahankaWhitefield
# 3               BTM LayoutYelahankaWhitefieldAmbalipura
# 4      BTM LayoutYelahankaWhitefieldAmbalipuraYelahanka
# 5     BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 6     BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 7     BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 8     BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 9     BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 10    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 11    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 12    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 13    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 14    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 15    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 16    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 17    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 18    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 19    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 20    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 21    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 22    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 23    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 24    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 25    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 26    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 27    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 28    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 29    BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# ...                                                 ...
# 3470  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3471  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3472  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3473  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3474  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3475  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3476  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3477  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3478  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3479  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3480  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3481  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3482  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3483  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3484  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3485  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3486  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3487  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3488  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3489  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3490  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3491  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3492  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3493  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3494  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3495  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3496  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3497  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3498  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
# 3499  BTM LayoutYelahankaWhitefieldAmbalipuraYelahan...
#
#                                                   built     sqft  \
# 0                                  Super built-up  Area     1450
# 1              Super built-up  AreaSuper built-up  Area     3640
# 2     Super built-up  AreaSuper built-up  AreaSuper ...     4659
# 3     Super built-up  AreaSuper built-up  AreaSuper ...     6516
# 4     Super built-up  AreaSuper built-up  AreaSuper ...     8706
# 5     Super built-up  AreaSuper built-up  AreaSuper ...    10378
# 6     Super built-up  AreaSuper built-up  AreaSuper ...    11708
# 7     Super built-up  AreaSuper built-up  AreaSuper ...    13380
# 8     Super built-up  AreaSuper built-up  AreaSuper ...    15237
# 9     Super built-up  AreaSuper built-up  AreaSuper ...    16337
# 10    Super built-up  AreaSuper built-up  AreaSuper ...    17356
# 11    Super built-up  AreaSuper built-up  AreaSuper ...    18375
# 12    Super built-up  AreaSuper built-up  AreaSuper ...    20047
# 13    Super built-up  AreaSuper built-up  AreaSuper ...    21590
# 14    Super built-up  AreaSuper built-up  AreaSuper ...    23133
# 15    Super built-up  AreaSuper built-up  AreaSuper ...    24333
# 16    Super built-up  AreaSuper built-up  AreaSuper ...    26190
# 17    Super built-up  AreaSuper built-up  AreaSuper ...    27974
# 18    Super built-up  AreaSuper built-up  AreaSuper ...    29517
# 19    Super built-up  AreaSuper built-up  AreaSuper ...    30847
# 20    Super built-up  AreaSuper built-up  AreaSuper ...    33037
# 21    Super built-up  AreaSuper built-up  AreaSuper ...    34894
# 22    Super built-up  AreaSuper built-up  AreaSuper ...    35994
# 23    Super built-up  AreaSuper built-up  AreaSuper ...    37666
# 24    Super built-up  AreaSuper built-up  AreaSuper ...    38685
# 25    Super built-up  AreaSuper built-up  AreaSuper ...    39785
# 26    Super built-up  AreaSuper built-up  AreaSuper ...    41115
# 27    Super built-up  AreaSuper built-up  AreaSuper ...    42658
# 28    Super built-up  AreaSuper built-up  AreaSuper ...    43858
# 29    Super built-up  AreaSuper built-up  AreaSuper ...    45308
# ...                                                 ...      ...
# 3470  Super built-up  AreaSuper built-up  AreaSuper ...  5343162
# 3471  Super built-up  AreaSuper built-up  AreaSuper ...  5344612
# 3472  Super built-up  AreaSuper built-up  AreaSuper ...  5345942
# 3473  Super built-up  AreaSuper built-up  AreaSuper ...  5346961
# 3474  Super built-up  AreaSuper built-up  AreaSuper ...  5348291
# 3475  Super built-up  AreaSuper built-up  AreaSuper ...  5349741
# 3476  Super built-up  AreaSuper built-up  AreaSuper ...  5350760
# 3477  Super built-up  AreaSuper built-up  AreaSuper ...  5352432
# 3478  Super built-up  AreaSuper built-up  AreaSuper ...  5353632
# 3479  Super built-up  AreaSuper built-up  AreaSuper ...  5354732
# 3480  Super built-up  AreaSuper built-up  AreaSuper ...  5355832
# 3481  Super built-up  AreaSuper built-up  AreaSuper ...  5357032
# 3482  Super built-up  AreaSuper built-up  AreaSuper ...  5359222
# 3483  Super built-up  AreaSuper built-up  AreaSuper ...  5360241
# 3484  Super built-up  AreaSuper built-up  AreaSuper ...  5361784
# 3485  Super built-up  AreaSuper built-up  AreaSuper ...  5363114
# 3486  Super built-up  AreaSuper built-up  AreaSuper ...  5364657
# 3487  Super built-up  AreaSuper built-up  AreaSuper ...  5365987
# 3488  Super built-up  AreaSuper built-up  AreaSuper ...  5367437
# 3489  Super built-up  AreaSuper built-up  AreaSuper ...  5368980
# 3490  Super built-up  AreaSuper built-up  AreaSuper ...  5370310
# 3491  Super built-up  AreaSuper built-up  AreaSuper ...  5372167
# 3492  Super built-up  AreaSuper built-up  AreaSuper ...  5374024
# 3493  Super built-up  AreaSuper built-up  AreaSuper ...  5375881
# 3494  Super built-up  AreaSuper built-up  AreaSuper ...  5377553
# 3495  Super built-up  AreaSuper built-up  AreaSuper ...  5378572
# 3496  Super built-up  AreaSuper built-up  AreaSuper ...  5380022
# 3497  Super built-up  AreaSuper built-up  AreaSuper ...  5381352
# 3483  ResaleResaleResaleResaleResaleResaleResaleResa...    26460  14654
# 3484  ResaleResaleResaleResaleResaleResaleResaleResa...    26470  14657
# 3485  ResaleResaleResaleResaleResaleResaleResaleResa...    26480  14658
# 3486  ResaleResaleResaleResaleResaleResaleResaleResa...    26490  14661
# 3487  ResaleResaleResaleResaleResaleResaleResaleResa...    26500  14662
# 3488  ResaleResaleResaleResaleResaleResaleResaleResa...    26505  14663
# 3489  ResaleResaleResaleResaleResaleResaleResaleResa...    26515  14666
# 3490  ResaleResaleResaleResaleResaleResaleResaleResa...    26525  14667
# 3491  ResaleResaleResaleResaleResaleResaleResaleResa...    26540  14671
# 3492  ResaleResaleResaleResaleResaleResaleResaleResa...    26555  14675
# 3493  ResaleResaleResaleResaleResaleResaleResaleResa...    26570  14679
# 3494  ResaleResaleResaleResaleResaleResaleResaleResa...    26580  14685
# 3495  ResaleResaleResaleResaleResaleResaleResaleResa...    26581  14687
# 3496  ResaleResaleResaleResaleResaleResaleResaleResa...    26586  14688
# 3497  ResaleResaleResaleResaleResaleResaleResaleResa...    26596  14689
# 3498  ResaleResaleResaleResaleResaleResaleResaleResa...    26606  14690
# 3499  ResaleResaleResaleResaleResaleResaleResaleResa...    26607  14692
#
#      totalFloor    bhk
# 0             4      1
# 1             9      4
# 2            14      6
# 3            19     10
# 4            24     13
# 5            34     19
# 6            38     20
# 7            48     26
# 8            53     30
# 9            57     33
# 10           62     35
# 11           67     37
# 12           77     43
# 13           81     46
# 14           85     49
# 15           89     50
# 16           94     54
# 17          112     72
# 18          116     75
# 19          120     76
# 20          125     79
# 21          130     83
# 22          134     86
# 23          144     92
# 24          149     94
# 25          153     97
# 26          157     98
# 27          161    101
# 28          165    102
# 29          169    103
# ...         ...    ...
# 3470      22163  14627
# 3471      22167  14628
# 3472      22171  14629
# 3473      22176  14631
# 3474      22180  14632
# 3475      22184  14633
# 3476      22189  14635
# 3477      22199  14641
# 3478      22203  14642
# 3479      22207  14645
# 3480      22211  14648
# 3481      22215  14649
# 3482      22220  14652
# 3483      22225  14654
# 3484      22229  14657
# 3485      22233  14658
# 3486      22237  14661
# 3487      22241  14662
# 3488      22245  14663
# 3489      22249  14666
# 3490      22253  14667
# 3491      22258  14671
# 3492      22263  14675
# 3493      22268  14679
# 3494      22278  14685
# 3495      22283  14687
# 3496      22287  14688
# 3497      22291  14689
# 3498      22295  14690
# 3499      22300  14692
#
# [3500 rows x 10 columns]
# cumulative min or max                                       :        Unnamed: 0    price                 place                 built  sqft  \
# 0          1341  6300000            BTM Layout  Super built-up  Area  1450
# 1          1341  6300000            BTM Layout  Super built-up  Area  1450
# 2           816  3800000            BTM Layout  Super built-up  Area  1019
# 3           816  3800000            Ambalipura  Super built-up  Area  1019
# 4           816  3800000            Ambalipura  Super built-up  Area  1019
# 5           816  3800000            Ambalipura  Super built-up  Area  1019
# 6           703  3800000            Ambalipura  Super built-up  Area  1019
# 3498  Resale        1     1          4   1
# 3499  Resale        1     1          4   1
#
# [3500 rows x 10 columns]
# Remove duplicate row                                        :         Unnamed: 0     price                     place                 built  \
# 0           1341   6300000                BTM Layout  Super built-up  Area
# 1           2126  11500000                 Yelahanka  Super built-up  Area
# 2            816   3800000                Whitefield  Super built-up  Area
# 3           2708  10500000                Ambalipura  Super built-up  Area
# 4           1041  11500000                 Yelahanka  Super built-up  Area
# 5           2783  15000000       Devarabeesana Halli  Super built-up  Area
# 6            703   7350000            Yelachenahalli  Super built-up  Area
# 7             88  15000000       Devarabeesana Halli  Super built-up  Area
# 8           1973  10500000                Ambalipura  Super built-up  Area
# 9            256   4900000                  KR Puram  Super built-up  Area
# 10          1831   3800000                Whitefield  Super built-up  Area
# 11           464   3800000                Whitefield  Super built-up  Area
# 12          1102  15000000       Devarabeesana Halli  Super built-up  Area
# 13           902   4025000  Electronics City Phase 1  Super built-up  Area
# 14          2139   4025000  Electronics City Phase 1  Super built-up  Area
# 15           162   4800000      Abbaiah Reddy Layout        Built-up  Area
# 16            95  10500000                Ambalipura  Super built-up  Area
# 17           830   7900000            Subramanyapura  Super built-up  Area
# 18           581   4025000  Electronics City Phase 1  Super built-up  Area
# 19          1120   7350000            Yelachenahalli  Super built-up  Area
# 20          2559  11500000                 Yelahanka  Super built-up  Area
# 21           329  10500000                Ambalipura  Super built-up  Area
# 22          1783   4900000                  KR Puram  Super built-up  Area
# 23          2202  15000000       Devarabeesana Halli  Super built-up  Area
# 24          1073   3800000                Whitefield  Super built-up  Area
# 25          2005   4900000                  KR Puram  Super built-up  Area
# 26          2649   7350000            Yelachenahalli  Super built-up  Area
# 27           747   4025000  Electronics City Phase 1  Super built-up  Area
# 28           142   4800000      Abbaiah Reddy Layout        Built-up  Area
# 29          2677   6300000                BTM Layout  Super built-up  Area
# ...          ...       ...                       ...                   ...
# 3402         403   3800000                Whitefield  Super built-up  Area
# 3405        1994   4800000      Abbaiah Reddy Layout        Built-up  Area
# 3407          32   7900000            Subramanyapura  Super built-up  Area
# 3411        1769  15000000       Devarabeesana Halli  Super built-up  Area
# 3415         490  10500000                Ambalipura  Super built-up  Area
# 3417         515   4025000  Electronics City Phase 1  Super built-up  Area
# 3418        2213   3800000                Whitefield  Super built-up  Area
# 3419        2465  10500000                Ambalipura  Super built-up  Area
# 3421        2681  15000000       Devarabeesana Halli  Super built-up  Area
# 3429        2615   7900000            Subramanyapura  Super built-up  Area
# 3431         742  10500000                Ambalipura  Super built-up  Area
# 3433        2840   4025000  Electronics City Phase 1  Super built-up  Area
# 3435         557   4800000      Abbaiah Reddy Layout        Built-up  Area
# 3443        2441   7350000            Yelachenahalli  Super built-up  Area
# 3448        2272  11500000                 Yelahanka  Super built-up  Area
# 3450        2179  10500000                Ambalipura  Super built-up  Area
# 3454          57  15000000       Devarabeesana Halli  Super built-up  Area
# 3456         232   4025000  Electronics City Phase 1  Super built-up  Area
# 3458         596   3800000                Whitefield  Super built-up  Area
# 3495  1019  Resale         1      2           5    2
# 3496  1450  Resale         5      1           4    1
# 3497  1330  Resale        10      1           4    1
#
# [2001 rows x 10 columns]
# Romove missing Value                                        :         Unnamed: 0     price                     place                 built  \
# 0           1341   6300000                BTM Layout  Super built-up  Area
# 1           2126  11500000                 Yelahanka  Super built-up  Area
# 2            816   3800000                Whitefield  Super built-up  Area
# 3           2708  10500000                Ambalipura  Super built-up  Area
# 4           1041  11500000                 Yelahanka  Super built-up  Area
# 5           2783  15000000       Devarabeesana Halli  Super built-up  Area
# 6            703   7350000            Yelachenahalli  Super built-up  Area
# 7             88  15000000       Devarabeesana Halli  Super built-up  Area
# 8           1973  10500000                Ambalipura  Super built-up  Area
# ...
# 20           162      Abbaiah Reddy Layout        Built-up  Area  1200
# 21            95                Ambalipura  Super built-up  Area  1857
# 22           830            Subramanyapura  Super built-up  Area  1784
# 23           581  Electronics City Phase 1  Super built-up  Area  1543
# 24          1120            Yelachenahalli  Super built-up  Area  1330
# 25          2559                 Yelahanka  Super built-up  Area  2190
# 26           329                Ambalipura  Super built-up  Area  1857
# 27          1783                  KR Puram  Super built-up  Area  1100
# 28          2202       Devarabeesana Halli  Super built-up  Area  1672
# 29          1073                Whitefield  Super built-up  Area  1019
# 30          2005                  KR Puram  Super built-up  Area  1100
# 31          2649            Yelachenahalli  Super built-up  Area  1330
# 32           747  Electronics City Phase 1  Super built-up  Area  1543
# 33           142      Abbaiah Reddy Layout        Built-up  Area  1200
# 34          2677                BTM Layout  Super built-up  Area  1450
# 35          1258                  KR Puram  Super built-up  Area  1100
# ...          ...                       ...                   ...   ...
# 3470          66            Yelachenahalli  Super built-up  Area  1330
# 3471         175                BTM Layout  Super built-up  Area  1450
# 3472        1334                 Yelahanka  Super built-up  Area  2190
# 3473          94                BTM Layout  Super built-up  Area  1450
# 3474        2078                Whitefield  Super built-up  Area  1019
# 3475         119                Whitefield  Super built-up  Area  1019
# 3476         560                BTM Layout  Super built-up  Area  1450
# 3477        2421            Yelachenahalli  Super built-up  Area  1330
# 3478        2138                Whitefield  Super built-up  Area  1019
# 3479        2180            Yelachenahalli  Super built-up  Area  1330
# 3480        1108                BTM Layout  Super built-up  Area  1450
# 3481         836                Whitefield  Super built-up  Area  1019
# 3482        2011       Devarabeesana Halli  Super built-up  Area  1672
# 3483         496      Abbaiah Reddy Layout        Built-up  Area  1200
# 3484        1136                  KR Puram  Super built-up  Area  1100
# 3485        2166                  KR Puram  Super built-up  Area  1100
# 3486        1540      Abbaiah Reddy Layout        Built-up  Area  1200
# 3487         734                 Yelahanka  Super built-up  Area  2190
# 3488        2043                Whitefield  Super built-up  Area  1019
# 3489        2214  Electronics City Phase 1  Super built-up  Area  1543
# 3490        2240            Yelachenahalli  Super built-up  Area  1330
# 3491        1154  Electronics City Phase 1  Super built-up  Area  1543
# 3492        2771            Yelachenahalli  Super built-up  Area  1330
# 3493         114                BTM Layout  Super built-up  Area  1450
# 11           1           5  1019  Resale                Whitefield      2
# 12          10          10  1672  Resale       Devarabeesana Halli      6
# 13          10           4  1543  Resale  Electronics City Phase 1      3
# 14          10           4  1543  Resale  Electronics City Phase 1      3
# 15          10           4  1200  Resale      Abbaiah Reddy Layout      1
# 16          15           5  1857  Resale                Ambalipura      4
# 17           5          18  1784  Resale            Subramanyapura     18
# 18          10           4  1543  Resale  Electronics City Phase 1      3
# 19          10           4  1330  Resale            Yelachenahalli      1
# 20           5           5  2190  Resale                 Yelahanka      3
# 21          15           5  1857  Resale                Ambalipura      4
# 22           5           4  1100  Resale                  KR Puram      3
# 23          10          10  1672  Resale       Devarabeesana Halli      6
# 24           1           5  1019  Resale                Whitefield      2
# 25           5           4  1100  Resale                  KR Puram      3
# 26          10           4  1330  Resale            Yelachenahalli      1
# 27          10           4  1543  Resale  Electronics City Phase 1      3
# 28          10           4  1200  Resale      Abbaiah Reddy Layout      1
# 29           5           4  1450  Resale                BTM Layout      1
# 30           5           4  1100  Resale                  KR Puram      3
# ...        ...         ...   ...     ...                       ...    ...
# 3470         1           5  1019  Resale                Whitefield      2
# 3471         5           4  1450  Resale                BTM Layout      1
# 3472        10           4  1330  Resale            Yelachenahalli      1
# 3473         1           5  1019  Resale                Whitefield      2
# 3474        10           4  1330  Resale            Yelachenahalli      1
# 3475         5           4  1450  Resale                BTM Layout      1
# 3476         1           5  1019  Resale                Whitefield      2
# 3477        10          10  1672  Resale       Devarabeesana Halli      6
# 3478        10           4  1200  Resale      Abbaiah Reddy Layout      1
# 3479         5           4  1100  Resale                  KR Puram      3
# 3480         5           4  1100  Resale                  KR Puram      3
# 3481        10           4  1200  Resale      Abbaiah Reddy Layout      1
# 3482         5           5  2190  Resale                 Yelahanka      3
# 3483         1           5  1019  Resale                Whitefield      2
# 3484        10           4  1543  Resale  Electronics City Phase 1      3
# 3485        10           4  1330  Resale            Yelachenahalli      1
# 3486        10           4  1543  Resale  Electronics City Phase 1      3
# 3487        10           4  1330  Resale            Yelachenahalli      1
# 3488         5           4  1450  Resale                BTM Layout      1
# 3489        10           4  1543  Resale  Electronics City Phase 1      3
# 3490        10           4  1330  Resale            Yelachenahalli      1
# 3491        15           5  1857  Resale                Ambalipura      4
# 3492        15           5  1857  Resale                Ambalipura      4
# 3493        15           5  1857  Resale                Ambalipura      4
# 3494        10          10  1672  Resale       Devarabeesana Halli      6
# 3495         1           5  1019  Resale                Whitefield      2
# 3496         5           4  1450  Resale                BTM Layout      1
# 3497        10           4  1330  Resale            Yelachenahalli      1
# 3498        10           4  1200  Resale      Abbaiah Reddy Layout      1
# 3499         1           5  1019  Resale                Whitefield      2
#
#                      built  bhk  Unnamed: 0
# 0     Super built-up  Area    1        1341
# 1     Super built-up  Area    3        2126
# 3     Super built-up  Area    4        2708
# 4     Super built-up  Area    3        1041
# 5     Super built-up  Area    6        2783
# 6     Super built-up  Area    1         703
# 7     Super built-up  Area    6          88
# 8     Super built-up  Area    4        1973
# 9     Super built-up  Area    3         256
# 10    Super built-up  Area    2        1831
# 11    Super built-up  Area    2         464
# 12    Super built-up  Area    6        1102
# 13    Super built-up  Area    3         902
# 14    Super built-up  Area    3        2139
# 15          Built-up  Area    1         162
# 16    Super built-up  Area    4          95
# 17    Super built-up  Area   18         830
# 18    Super built-up  Area    3         581
# 19    Super built-up  Area    1        1120
# 20    Super built-up  Area    3        2559
# 21    Super built-up  Area    4         329
# 22    Super built-up  Area    3        1783
# 23    Super built-up  Area    6        2202
# 24    Super built-up  Area    2        1073
# 25    Super built-up  Area    3        2005
# 26    Super built-up  Area    1        2649
# 27    Super built-up  Area    3         747
# 28          Built-up  Area    1         142
# 29    Super built-up  Area    1        2677
# 30    Super built-up  Area    3        1258
# ...                    ...  ...         ...
# 3470  Super built-up  Area    2         119
# 3471  Super built-up  Area    1         560
# 3472  Super built-up  Area    1        2421
# 3473  Super built-up  Area    2        2138
# 3474  Super built-up  Area    1        2180
# 3475  Super built-up  Area    1        1108
# 3476  Super built-up  Area    2         836
# 3477  Super built-up  Area    6        2011
# 3478        Built-up  Area    1         496
# 3479  Super built-up  Area    3        1136
# 3480  Super built-up  Area    3        2166
# 3481        Built-up  Area    1        1540
# 3482  Super built-up  Area    3         734
# 3483  Super built-up  Area    2        2043
# 3484  Super built-up  Area    3        2214
# 3485  Super built-up  Area    1        2240
# 3486  Super built-up  Area    3        1154
# 3487  Super built-up  Area    1        2771
# 3488  Super built-up  Area    1         114
# 3489  Super built-up  Area    3        2785
# 3490  Super built-up  Area    1        2271
# 3491  Super built-up  Area    4        1629
# 3492  Super built-up  Area    4         227
# 3493  Super built-up  Area    4        1282
# 3494  Super built-up  Area    6         595
# 3495  Super built-up  Area    2         636
# 3496  Super built-up  Area    1        1664
# 3497  Super built-up  Area    1        1252
# 3498        Built-up  Area    1         903
# 3499  Super built-up  Area    2        2183
#
# [3496 rows x 9 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-542-cb2f9e8a5fb6> in <module>()
# ----> 1 getDataAllDetails(data=data)
#
# <ipython-input-540-79a7615344e6> in getDataAllDetails(data)
#      82     print("Equivalent to `shift` without copying data                     :  ",data.slice_shift(axis=0,periods=5))
#      83     print("Sort object by labels (along an axis=0, default)               :  ",data.sort_index(axis=1,ascending=False))
# ---> 84     print("Sort by the values along either axis                           :  ",data.sort_values(by=["price","yearsOld"],axis=0,ascending=False))
#      85     print("Sort multilevel index by chosen axis level(sort based on words):  ",data.sortlevel(level=0, axis=1, ascending=True))
#      86     #print("Check it  :  ",data.stack(),data.sub,data.subtract())
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4409             for x in by:
#    4410                 k = self._get_label_or_level_values(x, axis=axis,
# -> 4411                                                     stacklevel=stacklevel)
#    4412                 keys.append(k)
#    4413             indexer = lexsort_indexer(keys, orders=ascending,
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'price'
